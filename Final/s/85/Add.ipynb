# %% [markdown]
# ## Add two positive number and return positive number
# ## Jagadeesh Vasudevamurthy

# %%
############################################################
# Exam.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################

class Solution:
    def sum(self, num1: int, num2: int) -> int:
        ans = [None] 
        work = [0] # work done by alg
        if (num1 >= 0 and num2 >= 0):
            s = Exam(num1,num2,ans,work)
        elif (num1 < 0 and num2 < 0):
            s = Exam(-num1,-num2,ans,work)
            ans[0] = -(ans[0])
        else:
            ans[0] = num1 + num2;
        return ans[0]

########################################
#Nothing can be changed in class Exam
########################################
class Exam:
    def __init__(self, a:'int', b:'int', ans, work):
        #NOTHING CAN BE CHANGED BELOW
        self._a = a
        self._b = b
        self._ans = ans 
        self._work = work 
        self._add()

    ########################################
    #  ZERO marks will be given if you don't use this routine
    #  NOTHING CAN BE CHANGED BELOW
    # _add1(5,3,1) returns [0,9]
    # _add1(5,9,1) returns [1,5]
    # _add(10,11,1) will crash.
    # a < 9
    # b < 9
    # c < 2
    ########################################
    def _add1(self, a:'int', b:'int', c:'int')->'[carry,sum]':
      assert(a >= 0 and a < 10)
      assert(b >= 0 and b < 10)
      assert(c >= 0 and c < 2)
      self._work[0] += 1
      l = [0,0]
      tsum = a + b + c
      if (tsum > 9):
        l[0] = 1
        l[1] = tsum - 10
      else:
        l[1] = tsum
      return l

    ####################################################
    # WRITE CODE BELOW
    ####################################################
    def _add(self)->'int':
        # REMOVE THIS LINE. WRITE CODE BELOW
        # ZERO marks will be given if you use list[], string, set or dict
        # MUST USE self._add1 to add each digit of the number
        # Can use anything from the language (cannot use library) for assembling final answer
        pass

# %% [markdown]
# ##  CANNOT CHANGE ANYTHING BELOW

# %% [markdown]
# ## TEST BENCH
# ## NOTHING CAN BE CHANED BELOW

# %%
############################################################
# ExamTest.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################

############################################################
#     NOTHING CAN BE CHANGED IN THIS FILE
###########################################################

############################################################
# All imports
###########################################################
#from Exam import *


class ExamTest():
    def __init__(self):
        self._no = 0 
        self._show = False
        self._testBench()

    def _testBench(self):
        self.basic_tests()
        print("All basic tests passed")
        print("You got 50 marks")
        print("I will see how you can pass my Hidden tests, which I will post after exam")
        print("Note Max marks you can get is 85. If hidden tests fails. you will get less marks")
        self._hidden_test()

    #Private function
    def _test1(self,a:'int', b:'int')->'None':
        ans = [None] 
        work = [0] 
        s = Exam(a,b,ans,work)
           
    
    def _hidden_test(self):
        pass
             

    def basic_tests(self):
        a = 1 
        b = 2 
        self._test1(a,b)
        
        

############################################################
# main 
# YOU CANNOT CHANGE ANYTHING BELOW
###########################################################
def main():
    print("Testing ExamTest.py Starts")
    s = ExamTest()
    print("All tests passed. You are a genius")
    print("If you liked this problem send me a box of chocolates")
    print("FILL Complexity of my algorithm. Will lose  10 marks if you don't fill:---------------------------------")
    print("Testing ExamTest.py ENDS")

############################################################
# main
###########################################################
if (__name__    == '__main__'):
    main()
